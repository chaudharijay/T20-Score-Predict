# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# 1           NaN  Melbourne Cricket Ground
# 2           NaN  Melbourne Cricket Ground
# 3           NaN  Melbourne Cricket Ground
# 4           NaN  Melbourne Cricket Ground
# ...         ...                       ...
# 115320  Colombo       R Premadasa Stadium
# 115321  Colombo       R Premadasa Stadium
# 115322  Colombo       R Premadasa Stadium
# 115323  Colombo       R Premadasa Stadium
# 115324  Colombo       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [63888 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [50501 rows x 7 columns]

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\190681986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 0       Melbourne              0
# 1       Melbourne              0
# 2       Melbourne              1
# 3       Melbourne              3
# 4       Melbourne              3
# ...           ...            ...
# 115320    Colombo            125
# 115321    Colombo            125
# 115322    Colombo            125
# 115323    Colombo            127
# 115324    Colombo            128
#
# [50501 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\2777558413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\2777558413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no
# 0       Melbourne              0    0       1
# 1       Melbourne              0    0       2
# 2       Melbourne              1    0       3
# 3       Melbourne              3    0       4
# 4       Melbourne              3    0       5
# ...           ...            ...  ...     ...
# 115320    Colombo            125   19       3
# 115321    Colombo            125   19       4
# 115322    Colombo            125   19       5
# 115323    Colombo            127   19       6
# 115324    Colombo            128   19       7
#
# [50501 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\562775579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled
# 0       Melbourne              0    0       1             1
# 1       Melbourne              0    0       2             2
# 2       Melbourne              1    0       3             3
# 3       Melbourne              3    0       4             4
# 4       Melbourne              3    0       5             5
# ...           ...            ...  ...     ...           ...
# 115320    Colombo            125   19       3           117
# 115321    Colombo            125   19       4           118
# 115322    Colombo            125   19       5           119
# 115323    Colombo            127   19       6           120
# 115324    Colombo            128   19       7           121
#
# [50501 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled  balls_left
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
# [50501 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\540685528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\540685528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[118], line 3
#       1 df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
#       2 df['player_dismissed'] = df['player_dismissed'].astype('int')
# ----> 3 df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
#       4 df['wickets_left'] = 10 - df['player_dismissed']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:4936, in GroupBy.cumsum(self, axis, *args, **kwargs)
#    4933     f = lambda x: x.cumsum(axis=axis, **kwargs)
#    4934     return self._python_apply_general(f, self._selected_obj, is_transform=True)
# -> 4936 return self._cython_transform("cumsum", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1702, in DataFrameGroupBy._cython_transform(self, how, numeric_only, axis, **kwargs)
#    1696     return self._grouper._cython_operation(
#    1697         "transform", bvalues, how, 1, **kwargs
#    1698     )
#    1700 # We could use `mgr.apply` here and not have to set_axis, but
#    1701 #  we would have to do shape gymnastics for ArrayManager compat
# -> 1702 res_mgr = mgr.grouped_reduce(arr_func)
#    1703 res_mgr.set_axis(1, mgr.axes[1])
#    1705 res_df = self.obj._constructor_from_mgr(res_mgr, axes=res_mgr.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1696, in DataFrameGroupBy._cython_transform.<locals>.arr_func(bvalues)
#    1695 def arr_func(bvalues: ArrayLike) -> ArrayLike:
# -> 1696     return self._grouper._cython_operation(
#    1697         "transform", bvalues, how, 1, **kwargs
#    1698     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:831, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     829 ids, _, _ = self.group_info
#     830 ngroups = self.ngroups
# --> 831 return cy_op.cython_operation(
#     832     values=values,
#     833     axis=axis,
#     834     min_count=min_count,
#     835     comp_ids=ids,
#     836     ngroups=ngroups,
#     837     **kwargs,
#     838 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:550, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     539 if not isinstance(values, np.ndarray):
#     540     # i.e. ExtensionArray
#     541     return values._groupby_op(
#     542         how=self.how,
#     543         has_dropped_na=self.has_dropped_na,
#    (...)
#     547         **kwargs,
#     548     )
# --> 550 return self._cython_op_ndim_compat(
#     551     values,
#     552     min_count=min_count,
#     553     ngroups=ngroups,
#     554     comp_ids=comp_ids,
#     555     mask=None,
#     556     **kwargs,
#     557 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:344, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     341     # otherwise we have OHLC
#     342     return res.T
# --> 344 return self._call_cython_op(
#     345     values,
#     346     min_count=min_count,
#     347     ngroups=ngroups,
#     348     comp_ids=comp_ids,
#     349     mask=mask,
#     350     result_mask=result_mask,
#     351     **kwargs,
#     352 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:401, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     398         result_mask = result_mask.T
#     400 out_shape = self._get_output_shape(ngroups, values)
# --> 401 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     402 values = self._get_cython_vals(values)
#     403 out_dtype = self._get_out_dtype(values.dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:200, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     197         pass
#     198     elif "object" not in f.__signatures__:
#     199         # raise NotImplementedError here rather than TypeError later
# --> 200         raise NotImplementedError(
#     201             f"function is not implemented for this dtype: "
#     202             f"[how->{how},dtype->{dtype_str}]"
#     203         )
#     204     return f
#     205 else:
#
# NotImplementedError: function is not implemented for this dtype: [how->cumsum,dtype->object]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 1
# 1              2    Australia    Sri Lanka   0.2     0                 1
# 2              2    Australia    Sri Lanka   0.3     1                 1
# 3              2    Australia    Sri Lanka   0.4     2                 1
# 4              2    Australia    Sri Lanka   0.5     0                 1
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 1
# 115321       964    Sri Lanka    Australia  19.4     0                 1
# 115322       964    Sri Lanka    Australia  19.5     0                 1
# 115323       964    Sri Lanka    Australia  19.6     2                 1
# 115324       964    Sri Lanka    Australia  19.7     1                 1
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
#              crr  last_five
# 0       0.000000        NaN
# 1       0.000000        NaN
# 2       2.000000        NaN
# 3       4.500000        NaN
# 4       3.600000        NaN
# ...          ...        ...
# 115320  6.410256       32.0
# 115321  6.355932       32.0
# 115322  6.302521       32.0
# 115323  6.350000       33.0
# 115324  6.347107       32.0
#
# [50501 rows x 14 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 1
# 1              2    Australia    Sri Lanka   0.2     0                 1
# 2              2    Australia    Sri Lanka   0.3     1                 1
# 3              2    Australia    Sri Lanka   0.4     2                 1
# 4              2    Australia    Sri Lanka   0.5     0                 1
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 1
# 115321       964    Sri Lanka    Australia  19.4     0                 1
# 115322       964    Sri Lanka    Australia  19.5     0                 1
# 115323       964    Sri Lanka    Australia  19.6     2                 1
# 115324       964    Sri Lanka    Australia  19.7     1                 1
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
#              crr  last_five
# 0       0.000000        NaN
# 1       0.000000        NaN
# 2       2.000000        NaN
# 3       4.500000        NaN
# 4       3.600000        NaN
# ...          ...        ...
# 115320  6.410256       32.0
# 115321  6.355932       32.0
# 115322  6.302521       32.0
# 115323  6.350000       33.0
# 115324  6.347107       32.0
#
# [50501 rows x 14 columns]

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    # Convert 'runs' to numeric before calculating rolling sum
    last_five.extend(groups.get_group(id)['runs'].astype(float).rolling(window=30).sum().values.tolist())

print(last_five)
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 43.0, 44.0, 45.0, 44.0, 42.0, 43.0, 41.0, 41.0, 41.0, 42.0, 42.0, 39.0, 38.0, 39.0, 38.0, 39.0, 40.0, 37.0, 41.0, 42.0, 42.0, 44.0, 44.0, 40.0, 39.0, 37.0, 35.0, 31.0, 27.0, 26.0, 31.0, 31.0, 30.0, 31.0, 31.0, 32.0, 31.0, 31.0, 36.0, 37.0, 37.0, 37.0, 37.0, 36.0, 36.0, 36.0, 36.0, 35.0, 32.0, 32.0, 31.0, 29.0, 29.0, 31.0, 32.0, 32.0, 32.0, 33.0, 36.0, 37.0, 37.0, 39.0, 41.0, 40.0, 41.0, 41.0, 42.0, 44.0, 39.0, 43.0, 45.0, 48.0, 48.0, 48.0, 49.0, 49.0, 49.0, 51.0, 51.0, 51.0, 52.0, 52.0, 53.0, 53.0, 53.0, 54.0, 53.0, 52.0, 50.0, 53.0, 47.0, 46.0, 45.0, 46.0, 47.0, 49.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 46.0, 52.0, 53.0, 57.0, 58.0, 59.0, 59.0, 59.0, 53.0, 53.0, 54.0, 50.0, 50.0, 49.0, 50.0, 47.0, 48.0, 49.0, 49.0, 46.0, 46.0, 51.0, 48.0, 48.0, 48.0, 44.0, 45.0, 42.0, 43.0, 40.0, 39.0, 39.0, 39.0, 36.0, 35.0, 39.0, 39.0, 38.0, 38.0, 37.0, 37.0, 38.0, 39.0, 41.0, 40.0, 40.0, 39.0, 38.0, 39.0, 42.0, 47.0, 42.0, 45.0, 45.0, 49.0, 49.0, 48.0, 47.0, 45.0, 45.0, 45.0, 40.0, 41.0, 41.0, 42.0, 37.0, 38.0, 39.0, 43.0, 46.0, 47.0, 47.0, 46.0, 50.0, 56.0, 57.0, 60.0, 59.0, 59.0, 55.0, 51.0, 51.0, 51.0, 53.0, 51.0, 51.0, 52.0, 53.0, 54.0, 53.0, 54.0, 53.0, 52.0, 51.0, 51.0, 51.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 33.0, 33.0, 36.0, 36.0, 34.0, 34.0, 35.0, 36.0, 36.0, 36.0, 32.0, 33.0, 32.0, 29.0, 23.0, 23.0, 26.0, 27.0, 27.0, 27.0, 27.0, 26.0, 27.0, 27.0, 27.0, 23.0, 24.0, 25.0, 27.0, 27.0, 28.0, 29.0, 26.0, 27.0, 26.0, 25.0, 25.0, 25.0, 25.0, 25.0, 26.0, 27.0, 27.0, 26.0, 28.0, 28.0, 25.0, 25.0, 25. ...

# %%
df['last_five'] = last_five
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_15516\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
#df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','']]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['wickets_left'] not in index"

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# match_id            0
# runs_x              0
# batting_team        0
# bowling_team        0
# ball                0
# runs_y              0
# player_dismissed    0
# city                0
# current_score       0
# over                0
# ball_no             0
# balls_bowled        0
# balls_left          0
# crr                 0
# last_five           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#        match_id  runs_x  batting_team bowling_team  ball  runs_y  \
# 19368       500     156  South Africa    Australia  14.4       0
# 45254       868     172       England     Pakistan  10.6       1
#
#        player_dismissed       city  current_score over ball_no  balls_bowled  \
# 19368                 1  Centurion             95   14       4            88
# 45254                 1      Dubai             78   10       6            66
#
#        balls_left       crr  last_five
# 19368          32  6.477273       26.0
# 45254          54  7.090909       32.0

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        match_id  batting_team  bowling_team  ball  runs_y  player_dismissed  \
# 43669       832  South Africa    Bangladesh  14.4       0                 1
# 23667       551     Australia      Pakistan  10.3       1                 1
# 15520       457   West Indies  South Africa  17.2       0                 1
# 31781       652      Pakistan   New Zealand   8.3       1                 1
# 2456         37   New Zealand     Australia  14.2       1                 1
# ...         ...           ...           ...   ...     ...               ...
# 27530       600       England      Pakistan  17.4       1                 1
# 31424       648   New Zealand    Bangladesh  10.3       1                 1
# 44111       836      Pakistan     Sri Lanka   6.1       2                 1
# 38832       771   New Zealand    Bangladesh  19.4       0                 1
# 39900       794     Sri Lanka       England  14.3       2                 1
#
#                city  current_score over ball_no  balls_bowled  balls_left  \
# 43669        Mirpur            122   14       4            88          32
# 23667     Melbourne             76   10       3            63          57
# 15520  Johannesburg            182   17       2           104          16
# 31781     Pallekele             80    8       3            51          69
# 2456       Auckland            114   14       2            86          34
# ...             ...            ...  ...     ...           ...         ...
# 27530         Dubai            122   17       4           106          14
# 31424     Pallekele             77   10       3            63          57
# 44111       Colombo             44    6       1            37          83
# 38832        Mirpur            200   19       4           118           2
# 39900    Chittagong            123   14       3            87          33
#
#              crr  last_five
# 43669   8.318182       27.0
# 23667   7.238095       28.0
# 15520  10.500000       37.0
# 31781   9.411765       54.0
# 2456    7.953488       24.0
# ...          ...        ...
# 27530   6.905660       36.0
# 31424   7.333333       45.0
# 44111   7.135135       36.0
# 38832  10.169492       53.0
# 39900   8.482759       55.0
#
# [30781 rows x 14 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[148], line 6
#       4 from sklearn.preprocessing import StandardScaler
#       5 from sklearn.ensemble import RandomForestRegressor
# ----> 6 from xgboost import XGBRegressor
#       7 from sklearn.metrics import r2_score,mean_absolute_error
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9870669474613561
# 1.7391097966945592

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '1.4.2'
